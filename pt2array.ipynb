# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
# # .ptファイルを読み込み
# tensor = torch.load('density_3d_arrray/density_2410_quarter.pt')
# middle_index=int((tensor.shape[1])/2)
# tensor_mid=tensor[:,middle_index,:]
# # テンソルをNumPy配列に変換
# array_mid = tensor_mid.cpu().numpy()
# np.save('density_2410_quarter_mid.npy', array_mid)

# %%
array=np.load("reconstructed/reconstructed2410_quater.npy")
middle_index=int((array.shape[1])/2)
array_mid=array[:,middle_index,:]

# %%
# 配列をMatplotlibでプロット
plt.imshow(np.rot90(array_mid,1), cmap='viridis')  # 適切なカラーマップを選択してください
plt.colorbar()  # カラーバーを表示

# プロットを表示
plt.show()
